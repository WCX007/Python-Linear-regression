# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('housing.csv')

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX      RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.5750  65.20  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.4210  78.90  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.1850  61.10  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.9980  45.80  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.1470  54.20  6.0622  3.0  222.0
#
#        PTRATIO     B  LSTAT  MEDV
# 0  15.30396.90  4.98   24.0   NaN
# 1  17.80396.90  9.14   21.6   NaN
# 2  17.80392.83  4.03   34.7   NaN
# 3  18.70394.63  2.94   33.4   NaN
# 4  18.70396.90  5.33   36.2   NaN

# %%
from sklearn.datasets import load_boston

# %%
 X, y = load_boston(return_X_y=True)

# %%
print(X.feature_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-1d2af1d5fcb1> in <module>
# ----> 1 print(X.feature_names)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'feature_names'

# %%
print(y[2])
# Out:
# 34.7

# %%
boston = load_boston()

# %%
data = boston.data
target = boston.target

# %%
print(data.shape)
# Out:
# (506, 13)

# %%
data_csv = pd.DataFrame(data,columns=boston.feature_names)

# %%
data_csv.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
data_csv['price'] = target

# %%
data_csv.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
data_csv.rename(columns={'price':'PRICE'},inplace=True)

# %%
data_csv.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
data_csv.to_csv('')
